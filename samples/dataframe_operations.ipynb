# %%
# This section enables to use the module code referenced in the repo
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Imports for the excercise
import pandas as pd 
import logging
import numpy as np
import arcus.ml.dataframes as adf

# %% [markdown]
# ## Loading a data frame
#
# 1. Loading of a dataset

# %%
import pandas as pd
df = pd.read_csv('../tests/resources/datasets/car-fuel.csv')
df.head(4)
# Out:
#   distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0       28       5     26        21,5            12      NaN      E10   0
# 1       12     4,2     30        21,5            13      NaN      E10   0
# 2     11,2     5,5     38        21,5            15      NaN      E10   0
# 3     12,9     3,9     36        21,5            14      NaN      E10   0
#
#    rain  sun refill liters refill gas
# 0     0    0            45        E10
# 1     0    0           NaN        NaN
# 2     0    0           NaN        NaN
# 3     0    0           NaN        NaN

# %% [markdown]
# ## Plotting distributions of features of the data set

# %% [markdown]
# ### Default plotting
#
# - All numeric features will be plotted automatically

# %%
_, axes = adf.plot_features(df)
# Out:
# Exception in printing column speed : 0 0 too many indices for array
# Exception in printing column temp_outside : 0 1 too many indices for array
# Exception in printing column AC : 0 2 too many indices for array
# Exception in printing column rain : 0 3 too many indices for array
# Exception in printing column sun : 0 4 too many indices for array

# %%
_, axes = adf.plot_features(df, fig_size=(15,8), grid_shape=(2,3))

# %%
_, axes = adf.plot_features(df, fig_size=(15,8), grid_shape=(2,2), column_names=['speed', 'temp_outside', 'sun', 'rain'])

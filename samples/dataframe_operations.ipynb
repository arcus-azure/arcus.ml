# %%
# This section enables to use the module code referenced in the repo
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Imports for the excercise
import pandas as pd 
import logging
import numpy as np
import arcus.ml.dataframes as adf

# %% [markdown]
# ## Loading a data frame
#
# 1. Loading of a dataset

# %%
import pandas as pd
df = pd.read_csv('../tests/resources/datasets/car-fuel.csv')
df.head(4)
# Out:
#   distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0       28       5     26        21,5            12      NaN      E10   0
# 1       12     4,2     30        21,5            13      NaN      E10   0
# 2     11,2     5,5     38        21,5            15      NaN      E10   0
# 3     12,9     3,9     36        21,5            14      NaN      E10   0
#
#    rain  sun refill liters refill gas
# 0     0    0            45        E10
# 1     0    0           NaN        NaN
# 2     0    0           NaN        NaN
# 3     0    0           NaN        NaN

# %% [markdown]
# ## Plotting distributions of features of the data set

# %% [markdown]
# ### Default plotting
#
# - All numeric features will be plotted automatically

# %%
_, axes = adf.plot_features(df)

# %%
_, axes = adf.plot_features(df, fig_size=(15,8), grid_shape=(2,3))

# %%
_, axes = adf.plot_features(df, fig_size=(15,8), grid_shape=(2,2), column_names=['speed', 'temp_outside', 'sun', 'rain'])

# %%
_, axes = adf.plot_features(df, fig_size=(15,4), column_names=['speed', 'temp_outside', 'sun', 'rain'])

# %% [markdown]
# ## Dataframe class distribution

# %%
df = pd.read_csv('../tests/resources/datasets/car-fuel.csv')
df.tail(4)
# Out:
#     distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 384     16,1     4,3     38          25            31       AC     SP98   1
# 385       16     3,8     45          25            19      NaN     SP98   0
# 386     15,4     4,6     42          25            31       AC     SP98   1
# 387     14,7       5     25          25            30       AC     SP98   1
#
#      rain  sun refill liters refill gas
# 384     0    0           NaN        NaN
# 385     0    0           NaN        NaN
# 386     0    0           NaN        NaN
# 387     0    0           NaN        NaN

# %%
_df = adf.distribute_class(df, 'gas_type', 5, False)
display(_df)
# Out:
#     distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 332      4,8     4,7     26          25            18      NaN      E10   0
# 261     24,5     3,9     50         NaN            15      sun      E10   0
# 19      11,8     4,7     40        21,5             4      NaN      E10   0
# 8        4,9     6,4     26        21,5             4      NaN      E10   0
# 149     36,9     4,8     52        21,5             5      NaN      E10   0
# 294      8,3     4,9     26          22            23      NaN     SP98   0
# 225     11,8     4,5     39        22,5             3      NaN     SP98   0
# 324     22,1     3,9     29          22            26      NaN     SP98   0
# 318      211     4,6     80          22            20      NaN     SP98   0
# 93      12,4     4,7     43         NaN            10      NaN     SP98   0
#
#      rain  sun refill liters refill gas
# 332     0    0           NaN        NaN
# 261     0    1           NaN        NaN
# ...

# %%
_df = adf.distribute_class(df, 'gas_type', 8)
display(_df)
# Out:
#    distance consume  speed temp_inside  temp_outside specials gas_type  AC  \
# 0        16     3,9     40          22            10      NaN     SP98   0
# 1      11,8       5     29        21,5            10      NaN      E10   0
# 2      25,9     4,1     43          22            24      NaN     SP98   0
# 3      12,3     6,1     40        21,5             6      NaN      E10   0
# 4      13,1     6,1     46        21,5             6     rain     SP98   0
# 5        13     5,7     38        22,5             3  AC rain     SP98   1
# 6       6,4     4,4     37         NaN            10      NaN     SP98   0
# 7        16       4     43          22            16      NaN      E10   0
# 8      24,8     4,6     55          23             3      NaN     SP98   0
# 9      12,3     5,1     55        22,5             8      NaN      E10   0
# 10     17,3       5     61        21,5             6  AC rain      E10   1
# ...

# %%
_onehot_encoded_df = adf.one_hot_encode(df, 'gas_type', drop_column=True, prefix='gt')
display(_onehot_encoded_df)
# Out:
#     distance consume  speed temp_inside  temp_outside specials  AC  rain  sun  \
# 0         28       5     26        21,5            12      NaN   0     0    0
# 1         12     4,2     30        21,5            13      NaN   0     0    0
# 2       11,2     5,5     38        21,5            15      NaN   0     0    0
# 3       12,9     3,9     36        21,5            14      NaN   0     0    0
# 4       18,5     4,5     46        21,5            15      NaN   0     0    0
# 5        8,3     6,4     50        21,5            10      NaN   0     0    0
# 6        7,8     4,4     43        21,5            11      NaN   0     0    0
# 7       12,3       5     40        21,5             6      NaN   0     0    0
# 8        4,9     6,4     26        21,5             4      NaN   0     0    0
# 9       11,9     5,3     30        21,5             9      NaN   0     0    0
# 10      12,4     5,6     42        21,5             4      NaN   0     0    0
# ...
